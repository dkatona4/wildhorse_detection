# %%
import os
import pandas as pd
import sys
import glob

# Must modify
black_path = '/home/wildhorse_project/detectron_pic/black/**/*.csv'
crop_path = '/home/wildhorse_project/detectron_pic/crop/**/*.csv'

def path_check(path, message):
    if glob.glob(path):
        print(message + " path - SUCCESS")
    else:
        print(message + " path - FAILED INVALID PATH: " + path)
        return False
    return True

result = pd.DataFrame()
# Check path definitions
if (path_check(crop_path, "Crop")):
    crop = pd.concat(map(pd.read_csv, glob.glob(crop_path)))
    result = result.append(crop)
if (path_check(black_path, "Black")):
    black = pd.concat(map(pd.read_csv, glob.glob(black_path)))
    result = result.append(black)

# result
    
rows = result.loc[result['Individual'] == 'pinty']
new = rows.groupby(['VideoID','Individual']).size().reset_index(name='counts')
new['Weight'] = new['counts']/len(rows)
new
# max_row = len(rows)
# unique_videoIDs= rows.VideoID.unique()
# for i in unique_videoIDs:
#     new = rows.loc[rows['VideoID'] == i].sample(weight = 0.13)
#     print(str(max_row) + ", " + str(len(new)) + ", " + str(i) )
# Out:
# Crop path - SUCCESS
# Black path - SUCCESS
#                                                    Path Individual  ID   Type  \
# 0     /home/wildhorse_project/detectron_pic/black/dr...      pinty  16   crop
# 1     /home/wildhorse_project/detectron_pic/black/dr...      pinty  16   crop
# 2     /home/wildhorse_project/detectron_pic/black/dr...      pinty  16   crop
# 3     /home/wildhorse_project/detectron_pic/black/dr...      pinty  16   crop
# 4     /home/wildhorse_project/detectron_pic/black/dr...      pinty  16   crop
# ...                                                 ...        ...  ..    ...
# 1161  /home/wildhorse_project/detectron_pic/black/dr...      vadoc   9  black
# 1162  /home/wildhorse_project/detectron_pic/black/dr...      vadoc   9  black
# 1163  /home/wildhorse_project/detectron_pic/black/dr...      vadoc   9  black
# 1164  /home/wildhorse_project/detectron_pic/black/dr...      vadoc   9  black
# 1165  /home/wildhorse_project/detectron_pic/black/dr...      vadoc   9  black
#
#      Record  VideoID
# 0     drone       52
# 1     drone       60
# 2     drone       57
# 3     drone       59
# 4     drone       56
# ...     ...      ...
# 1161  drone       26
# 1162  drone       69
# 1163  drone       65
# 1164  drone       72
# 1165  drone       69
#
# [47928 rows x 6 columns]
